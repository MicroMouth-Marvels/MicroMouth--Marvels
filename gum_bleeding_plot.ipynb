# %%
import matplotlib.pyplot as plt
from matplotlib.widgets import Cursor
import pandas as pd

# %%
def plot_participation(weeks, participant_data):
    # Convert participation status to colors
    colors = ['red' if status == 'Yes' else 'blue' for status in participant_data]

    # Plot
    plt.figure(figsize=(10, 5))
    for i in range(len(weeks) - 1):
        plt.plot([weeks[i], weeks[i + 1]], [participant_data[i], participant_data[i + 1]], color=colors[i], marker='o', linestyle='')
    plt.title('Participant Participation Over Weeks')
    plt.xlabel('Weeks')
    plt.ylabel('participant')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.tight_layout()
    plt.show()

weeks = ['01-22', '01-23', '01-24', '01-25', '01-26', '01-27', '01-28', '01-29', '01-30', '01-31', '02-01', '02-02', '02-03', '02-04', '02-05', '02-06']
participant_1 = ['No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'No', 'No']
participant_2 = ['No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No']


participant_3 = ['Yes', 'Yes', 'No', 'No', 'No',    'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No']


participant_4 = ['No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Yes', 'Yes', 'Yes']
participant_5 = ['No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No']

plot_participation(weeks, participant_1)
plot_participation(weeks, participant_2)
plot_participation(weeks, participant_3)
plot_participation(weeks, participant_4)
plot_participation(weeks, participant_5)

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.info()
#
# NameError: name 'df' is not defined
